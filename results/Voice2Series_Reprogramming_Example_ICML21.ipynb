# %% [markdown]
# # Voice2Series: Reprogramming Acoustic Models for Time Series Classification
#
# - Apache 2.0 License: Free Academic and Commericial Use.
#
# - Chao-Han Huck Yang et al. 2021 July Colab Demo
#
# [Paper ](http://proceedings.mlr.press/v139/yang21j/yang21j.pdf) | [Github](https://github.com/huckiyang/Voice2Series-Reprogramming)

# %%
! git clone https://github.com/huckiyang/Voice2Series-Reprogramming
# Out:
# fatal: destination path 'Voice2Series-Reprogramming' already exists and is not an empty directory.

# %%
! pip install kapre==0.2.0
! pip install tensorflow-gpu==2.1.0
# Out:
# ...
#   Using cached https://files.pythonhosted.org/packages/ec/78/b27f73e923becc6e79e18fe112cf75e3200d1ee35b0dba8fa46181bce56c/tensorflow_estimator-2.5.0-py2.py3-none-any.whl
# ...
#   Using cached https://files.pythonhosted.org/packages/b6/48/583c032b79ae5b3daa02225a675aeb673e58d2cb698e78510feceb11958c/gast-0.4.0-py3-none-any.whl
# ...
#   Using cached https://files.pythonhosted.org/packages/9d/74/9eae2bedd8201ab464308f42c601a12d79727a1c87f0c867fdefb212c6cf/h5py-3.1.0-cp37-cp37m-manylinux1_x86_64.whl
# ...
#   Using cached https://files.pythonhosted.org/packages/44/f5/7feea02a3fb54d5db827ac4b822a7ba8933826b36de21880518250b8733a/tensorboard-2.5.0-py3-none-any.whl
# ...
# ERROR: tensorflow-gpu 2.1.0 has requirement gast==0.2.2, but you'll have gast 0.4.0 which is incompatible.
# ERROR: tensorflow-gpu 2.1.0 has requirement tensorboard<2.2.0,>=2.1.0, but you'll have tensorboard 2.5.0 which is incompatible.
# ...

# %%
# !pip install h5py==2.10.0
# Out:
# ...
#   Using cached https://files.pythonhosted.org/packages/3f/c0/abde58b837e066bca19a3f7332d9d0493521d7dd6b48248451a9e3fe2214/h5py-2.10.0-cp37-cp37m-manylinux1_x86_64.whl
# ...
# ERROR: tensorflow 2.5.0 has requirement gast==0.4.0, but you'll have gast 0.2.2 which is incompatible.
# ERROR: tensorflow 2.5.0 has requirement h5py~=3.1.0, but you'll have h5py 2.10.0 which is incompatible.
# ERROR: tensorflow 2.5.0 has requirement tensorboard~=2.5, but you'll have tensorboard 2.1.1 which is incompatible.
# ERROR: tensorflow 2.5.0 has requirement tensorflow-estimator<2.6.0,>=2.5.0rc0, but you'll have tensorflow-estimator 2.1.0 which is incompatible.
# ...
#   Found existing installation: h5py 3.1.0
#     Uninstalling h5py-3.1.0:
#       Successfully uninstalled h5py-3.1.0
# ...

# %% [markdown]
# ## Model Training with Voice to Series
# - From a Frozen Pre-Trained Self-Attention Acoustic Model ([de Andrade et al. 2018](https://arxiv.org/abs/1808.08929) and Yang et al. ICASSP 2021 [link text](https://ieeexplore.ieee.org/stamp/stamp.jsp?arnumber=9413453))
# - Noted this is an example code. Please refer to the paper for loss validation details. Thanks.

# %%
# %cd Voice2Series-Reprogramming
# !python v2s_main.py --dataset 0 --eps 5 --mapping 3
# Out:
# /content/Voice2Series-Reprogramming
# 2021-07-19 06:17:38.477153: W tensorflow/stream_executor/platform/default/dso_loader.cc:55] Could not load dynamic library 'libnvinfer.so.6'; dlerror: libnvinfer.so.6: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/lib64-nvidia
# 2021-07-19 06:17:38.477307: W tensorflow/stream_executor/platform/default/dso_loader.cc:55] Could not load dynamic library 'libnvinfer_plugin.so.6'; dlerror: libnvinfer_plugin.so.6: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/lib64-nvidia
# 2021-07-19 06:17:38.477340: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:30] Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.
# tensorflow vr.  2.1.0 kapre vr.  0.2.0
# --- Use FordA Dataset
# --- X shape :  (500, 1) --- Num of Classes :  2
# ...

# %% [markdown]
# # Class Activation Mapping Results
#
# - Can V2S learn from both short time series input (e.g., ECG) and trainable noise?
# - The CAM Code is originally from QCNN-Speech (Yang et al. ICASSP 2021).

# %%
! python cam_v2s.py --dataset 5 --weight wNo5_map6-88-0.7662.h5 --mapping 6 --layer conv2d_1
# Out:
# 2021-07-19 06:21:28.573660: W tensorflow/stream_executor/platform/default/dso_loader.cc:55] Could not load dynamic library 'libnvinfer.so.6'; dlerror: libnvinfer.so.6: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/lib64-nvidia
# 2021-07-19 06:21:28.573766: W tensorflow/stream_executor/platform/default/dso_loader.cc:55] Could not load dynamic library 'libnvinfer_plugin.so.6'; dlerror: libnvinfer_plugin.so.6: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/lib64-nvidia
# 2021-07-19 06:21:28.573784: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:30] Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.
# tensorflow vr.  2.1.0 kapre vr.  0.2.0
# 2021-07-19 06:21:30.286959: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# ...

# %%
from IPython.display import Image
Image('/content/Voice2Series-Reprogramming/results/0719_0621_ts_No5.png') #Check your CAM result from Results and current date.

# %% [markdown]
# - Bib Reference
#
# @InProceedings{pmlr-v139-yang21j,
#   title = 	 {Voice2Series: Reprogramming Acoustic Models for Time Series Classification},
#   author =       {Yang, Chao-Han Huck and Tsai, Yun-Yun and Chen, Pin-Yu},
#   booktitle = 	 {Proceedings of the 38th International Conference on Machine Learning},
#   pages = 	 {11808--11819},
#   year = 	 {2021},
#   editor = 	 {Meila, Marina and Zhang, Tong},
#   volume = 	 {139},
#   series = 	 {Proceedings of Machine Learning Research},
#   month = 	 {18--24 Jul},
#   publisher =    {PMLR},
#   pdf = 	 {http://proceedings.mlr.press/v139/yang21j/yang21j.pdf},
#   url = 	 {http://proceedings.mlr.press/v139/yang21j.html},
# }
